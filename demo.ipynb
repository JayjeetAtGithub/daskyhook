# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
client = Client("tcp://10.10.1.1:8786")

# %%
client
# Out:
# <Client: 'tcp://10.10.1.1:8786' processes=8 threads=128, memory=501.47 GiB>

# %%
df = dd.read_parquet('/mnt/cephfs', engine='pyarrow', filters=[('total_amount', '>', 250)], format='parquet')

# %%
# %%time

df.compute()

# %%
df = dd.read_parquet('/mnt/cephfs', engine='pyarrow', filters=[('total_amount', '>', 250)], format='skyhook')

# %%
# %%time

df.compute()
# Out:
# CPU times: user 11 s, sys: 611 ms, total: 11.6 s
# Wall time: 9min 21s
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2  2017-02-01 01:53:49   2017-02-01 01:54:01                1
# 1          2  2017-02-01 09:11:56   2017-02-01 09:11:57                1
# 2          2  2017-02-01 10:01:08   2017-02-01 16:38:26                1
# 3          2  2017-02-01 11:46:02   2017-02-01 12:54:45                1
# 4          1  2017-02-01 16:01:34   2017-02-01 16:31:27                1
# ..       ...                  ...                   ...              ...
# 48         2  2017-02-04 17:12:46   2017-02-04 17:12:47                1
# 49         2  2017-02-04 17:21:41   2017-02-04 18:07:02                1
# 50         1  2017-02-04 19:24:32   2017-02-04 20:38:14                2
# 51         2  2017-02-04 22:08:12   2017-02-04 23:03:55                1
# 52         2  2017-02-04 22:34:48   2017-02-05 00:02:27                1
#
# ...

# %%
# !ceph -s
# Out:
#   cluster:
#     id:     85441d65-655e-4847-b3af-3ed689e1a782
#     health: HEALTH_WARN
#             mons are allowing insecure global_id reclaim
#
#   services:
#     mon: 3 daemons, quorum node1,node2,node3 (age 46h)
#     mgr: node3(active, since 46h)
#     mds: cephfs:1 {0=node1=up:active}
#     osd: 8 osds: 8 up (since 39h), 8 in (since 46h)
#
#   data:
#     pools:   3 pools, 273 pgs
#     objects: 9.05k objects, 263 GiB
#     usage:   796 GiB used, 936 GiB / 1.7 TiB avail
#     pgs:     273 active+clean
